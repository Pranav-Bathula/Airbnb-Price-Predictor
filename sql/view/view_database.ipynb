# %% [markdown]
# # Database Viewer
#
# This notebook provides an organized way to view and explore the SQLite database.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

current_dir = Path().resolve()

# Find project_root by looking for a "data" folder upwards
if (current_dir / "data").exists():
    project_root = current_dir
elif (current_dir.parent / "data").exists():
    project_root = current_dir.parent
elif (current_dir.parents[1] / "data").exists():
    project_root = current_dir.parents[1]
else:
    # fallback: assume grandparent is project root
    project_root = current_dir.parents[1]

data_dir = project_root / "data"
processed_dir = data_dir / "processed"

print("Project root:", project_root)
print("Data dir:    ", data_dir)
print("Processed dir:", processed_dir)
# Out:
# Project root: /Users/yg25/CSPROJECTS/Airbnb-Price-Predictor
# Data dir:     /Users/yg25/CSPROJECTS/Airbnb-Price-Predictor/data
# Processed dir: /Users/yg25/CSPROJECTS/Airbnb-Price-Predictor/data/processed

# %%
# city counts already from DB: df_city_counts

city_map = {
    "Boston":       {"folder": "Boston",        "processed": "Boston_listings_cleaned.csv"},
    "NYC":          {"folder": "NYC",           "processed": "NYC_listings_cleaned.csv"},
    "Washington DC":{"folder": "Washington_DC", "processed": "Washington_DC_listings_cleaned.csv"},
}

rows_raw = {}
rows_processed = {}

for city, info in city_map.items():
    raw_path = data_dir / info["folder"] / "listings.csv"
    proc_path = processed_dir / info["processed"]
    
    # raw
    if raw_path.exists():
        df_raw = pd.read_csv(raw_path)
        rows_raw[city] = len(df_raw)
    else:
        rows_raw[city] = None
        print(f"⚠ Raw file missing for {city}: {raw_path}")
    
    # processed
    if proc_path.exists():
        df_proc = pd.read_csv(proc_path)
        rows_processed[city] = len(df_proc)
    else:
        rows_processed[city] = None
        print(f"⚠ Processed file missing for {city}: {proc_path}")

summary = df_city_counts.copy()
summary = summary.rename(columns={"n_listings": "rows_in_db"})

summary["rows_raw_csv"] = summary["city"].map(rows_raw)
summary["rows_processed_csv"] = summary["city"].map(rows_processed)

summary["lost_in_cleaning"] = summary["rows_raw_csv"] - summary["rows_processed_csv"]
summary["lost_loading_to_db"] = summary["rows_processed_csv"] - summary["rows_in_db"]

summary
# Out:
#             city  rows_in_db  rows_raw_csv  rows_processed_csv  \
# 0         Boston        2524          4419                2670
# 1            NYC       14122         36111               14382
# 2  Washington DC        3985          6423                4075
#
#    lost_in_cleaning  lost_loading_to_db
# 0              1749                 146
# 1             21729                 260
# 2              2348                  90

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Set up database path
# This notebook is in sql/view/, so we need to go up two levels to get to project root
current_dir = Path().resolve()

# Try different possible locations
if (current_dir / "data").exists():
    # Running from project root
    project_root = current_dir
elif (current_dir.parent / "data").exists():
    # Running from sql/ directory
    project_root = current_dir.parent
elif (current_dir.parent.parent / "data").exists():
    # Running from sql/view/ directory
    project_root = current_dir.parent.parent
else:
    # Fallback: go up two levels from sql/view/
    project_root = current_dir.parent.parent

db_path = project_root / "data" / "airbnb.db"

print(f"Current directory: {current_dir}")
print(f"Project root: {project_root}")
print(f"Database: {db_path}")
print(f"Exists: {db_path.exists()}")
# Out:
# Current directory: /Users/yg25/CSPROJECTS/Airbnb-Price-Predictor/sql/view
# Project root: /Users/yg25/CSPROJECTS/Airbnb-Price-Predictor
# Database: /Users/yg25/CSPROJECTS/Airbnb-Price-Predictor/data/airbnb.db
# Exists: True

# %% [markdown]
# ## Database Overview

# %%
conn = sqlite3.connect(str(db_path))

# Get all tables
tables_query = "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"
tables = pd.read_sql_query(tables_query, conn)
# Filter out system tables and calendar
tables = tables[~tables['name'].isin(['calendar', 'sqlite_sequence'])]
print("📊 Tables in database:")
print(tables)

# Get row counts for each table
print("\n📈 Row counts:")
for table in tables['name']:
    count = pd.read_sql_query(f"SELECT COUNT(*) as count FROM {table}", conn)
    print(f"  {table}: {count['count'].iloc[0]:,} rows")
# Out:
# 📊 Tables in database:
#             name
# 0        listing
# 1  neighbourhood
#
# 📈 Row counts:
#   listing: 20,631 rows
#   neighbourhood: 295 rows

# %% [markdown]
# ## View Neighbourhood Table

# %%
df_neighbourhoods = pd.read_sql_query("SELECT * FROM neighbourhood ORDER BY borough, neighbourhood_name", conn)
print(f"Total neighbourhoods: {len(df_neighbourhoods)}")
print(f"\nBoroughs: {df_neighbourhoods['borough'].unique()}")
df_neighbourhoods.head(20)
# Out:
# Total neighbourhoods: 295
#
# Boroughs: [None 'Bronx' 'Brooklyn' 'Manhattan' 'Queens' 'Staten Island']
#     neighbourhood_id borough  \
# 0                231    None
# 1                232    None
# 2                233    None
# 3                234    None
# 4                235    None
# 5                257    None
# 6                258    None
# 7                259    None
# 8                260    None
# 9                261    None
# 10               236    None
# 11               237    None
# 12               262    None
# 13               263    None
# 14               264    None
# 15               265    None
# 16               266    None
# 17               238    None
# 18               267    None
# 19               239    None
#
#                                    neighbourhood_name
# 0                                             Allston
# 1                                            Back Bay
# 2                                         Bay Village
# 3                                         Beacon Hill
# 4                                            Brighton
# 5                Brightwood Park, Crestwood, Petworth
# 6                       Brookland, Brentwood, Langdon
# 7                          Capitol Hill, Lincoln Park
# 8     Capitol View, Marshall Heights, Benning Heights
# 9      Cathedral Heights, McLean Gardens, Glover Park
# 10                                        Charlestown
# 11                                          Chinatown
# 12  Cleveland Park, Woodley Park, Massachusetts Av...
# 13  Colonial Village, Shepherd Park, North Portal ...
# 14  Columbia Heights, Mt. Pleasant, Pleasant Plain...
# 15   Congress Heights, Bellevue, Washington Highlands
# 16  Deanwood, Burrville, Grant Park, Lincoln Heigh...
# 17                                         Dorchester
# 18                           Douglas, Shipley Terrace
# 19                                           Downtown

# %% [markdown]
# ## View Listing Table

# %%
# Sample listings with neighbourhood info
df_listings = pd.read_sql_query("""
    SELECT *
    FROM listing l
    LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
    LIMIT 30
""", conn)
df_listings
# Out:
#     listing_id  neighbourhood_id           city  host_id  host_name  \
# 0         2595               115            NYC     2845   Jennifer
# 1         3344               268  Washington DC     4957       A.J.
# 2         3686               276  Washington DC     4645       Vita
# 3         3781               240         Boston     4804      Frank
# 4         3943               271  Washington DC     5059       Vasa
# 5         4197               259  Washington DC     5061     Sandra
# 6         5506               251         Boston     8229      Terry
# 7         5589               279  Washington DC     6527        Ami
# 8         6695               251         Boston     8229      Terry
# 9         6848                96            NYC    15991      Allen
# 10        6872               102            NYC    16104  Kahshanna
# 11        6990               102            NYC    16800    Cynthia
# 12        7097                76            NYC    17571       Jane
# 13        7103               289  Washington DC    17633  Charlotte
# 14        8490                52            NYC    25183   Nathalie
# 15        8789               234         Boston    26988       Anne
# 16       10452                52            NYC    35935     Angela
# 17       10811               232         Boston    38997   Michelle
# 18       10813               232         Boston    38997   Michelle
# 19       10986               249         Boston    38997   Michelle
# 20       11785               261  Washington DC    32015     Teresa
# 21       12442               261  Washington DC    32015     Teresa
# 22       12937               165            NYC    50124    Orestes
# 23       12940                52            NYC    50148   Adreinne
# 24       13744               264  Washington DC    53927   Victoria
# 25       14218               261  Washington DC    32015     Teresa
# 26       14314                81            NYC    56246     Jeanne
# 27       16338                63            NYC    63613   Patricia
# 28       16580               103            NYC    64442       Reka
# 29       16821               103            NYC     4396      Casey
#
#     host_since  host_is_superhost        room_type  \
# 0   2008-09-09                  0  Entire home/apt
# 1   2008-12-10                  0  Entire home/apt
# 2   2008-11-26                  0     Private room
# 3   2008-12-03                  1  Entire home/apt
# 4   2008-12-12                  1     Private room
# 5   2008-12-12                  1     Private room
# 6   2009-02-19                  1  Entire home/apt
# 7   2009-01-13                  0  Entire home/apt
# 8   2009-02-19                  1  Entire home/apt
# 9   2009-05-06                  1  Entire home/apt
# 10  2009-05-07                  0     Private room
# 11  2009-05-12                  0     Private room
# 12  2009-05-17                  1     Private room
# 13  2009-05-18                  1  Entire home/apt
# 14  2009-07-10                  0  Entire home/apt
# 15  2009-07-22                  1  Entire home/apt
# 16  2009-09-03                  1     Private room
# 17  2009-09-16                  0  Entire home/apt
# 18  2009-09-16                  0  Entire home/apt
# 19  2009-09-16                  0  Entire home/apt
# 20  2009-08-16                  1  Entire home/apt
# 21  2009-08-16                  1     Private room
# 22  2009-10-31                  0     Private room
# 23  2009-10-31                  0  Entire home/apt
# 24  2009-11-13                  0  Entire home/apt
# 25  2009-08-16                  1     Private room
# 26  2009-11-21                  0  Entire home/apt
# 27  2009-12-16                  0     Private room
# 28  2009-12-19                  1     Private room
# 29  2008-11-19                  1     Private room
#
#                   property_type  accommodates  ...  estimated_revenue  \
# 0            Entire rental unit             1  ...                0.0
# 1                  Entire condo             2  ...                0.0
# 2          Private room in home             1  ...                0.0
# 3            Entire rental unit             2  ...                0.0
# 4     Private room in townhouse             2  ...            19434.0
# 5          Private room in home             1  ...             9216.0
# 6            Entire guest suite             2  ...             6966.0
# 7            Entire rental unit             3  ...                0.0
# 8                  Entire condo             4  ...             8064.0
# 9            Entire rental unit             3  ...            17280.0
# 10        Private room in condo             1  ...                0.0
# 11  Private room in rental unit             1  ...            17520.0
# 12  Private room in guest suite             2  ...            55080.0
# 13           Entire guest suite             2  ...                0.0
# 14                  Entire loft             5  ...                0.0
# 15           Entire rental unit             2  ...                0.0
# 16  Private room in rental unit             2  ...             5400.0
# 17           Entire rental unit             3  ...                0.0
# 18           Entire rental unit             2  ...            12928.0
# 19                 Entire condo             2  ...            24240.0
# 20           Entire rental unit             4  ...            11160.0
# 21         Private room in home             2  ...             6448.0
# 22    Private room in townhouse             3  ...            59160.0
# 23           Entire rental unit             2  ...            36240.0
# 24           Entire rental unit             2  ...                0.0
# 25         Private room in home             2  ...             7936.0
# 26           Entire rental unit             2  ...                0.0
# 27        Private room in condo             1  ...                0.0
# 28        Private room in condo             1  ...            57885.0
# 29  Private room in rental unit             1  ...            51510.0
#
#     first_review  last_review review_scores_rating  instant_bookable  \
# 0     2009-11-21   2022-06-21                 4.68                 0
# 1     2009-05-09   2016-08-31                 5.00                 0
# 2     2010-11-01   2023-08-30                 4.64                 0
# 3     2015-07-10   2024-08-09                 4.96                 0
# 4     2009-05-10   2025-05-27                 4.86                 0
# 5     2009-05-14   2025-05-20                 4.88                 0
# 6     2009-03-21   2025-07-28                 4.82                 0
# 7     2009-09-22   2023-08-17                 4.50                 0
# 8     2009-08-06   2025-07-29                 4.81                 0
# 9     2009-05-25   2025-06-09                 4.59                 0
# 10    2022-06-05   2022-06-05                 5.00                 0
# 11    2009-10-28   2025-05-27                 4.88                 0
# 12    2010-01-16   2025-09-23                 4.89                 1
# 13    2010-03-21   2022-06-03                 4.79                 0
# 14    2009-08-25   2023-10-16                 4.77                 0
# 15    2014-08-12   2024-05-15                 4.69                 0
# 16    2010-04-18   2025-03-31                 4.66                 0
# 17    2016-01-09   2019-07-22                 4.33                 0
# 18    2019-03-17   2025-06-30                 5.00                 0
# 19    2024-01-05   2025-03-31                 4.50                 0
# 20    2010-01-12   2025-05-31                 4.59                 0
# 21    2010-03-12   2024-12-20                 4.62                 1
# 22    2010-06-13   2025-09-26                 4.92                 1
# 23    2009-12-12   2025-05-31                 4.58                 0
# 24    2010-04-11   2023-11-14                 4.84                 0
# 25    2011-05-01   2025-02-28                 4.62                 0
# 26    2009-12-13   2024-09-30                 4.83                 0
# 27    2010-01-02   2023-12-22                 4.66                 0
# 28    2013-08-22   2025-09-04                 4.81                 0
# 29    2012-08-14   2025-09-29                 4.74                 0
#
#     calculated_host_listings_count  reviews_per_month  neighbourhood_id  \
# 0                                3               0.24               115
# 1                                2               0.05               268
# 2                                1               0.47               276
# 3                                1               0.21               240
# 4                                5               2.78               271
# 5                                2               0.34               259
# 6                               11               0.69               251
# 7                                1               0.50               279
# 8                               11               0.72               251
# 9                                1               0.98                96
# 10                               2               0.02               102
# 11                               1               1.28               102
# 12                               2               2.21                76
# 13                              22               0.49               289
# 14                               2               0.96                52
# 15                               4               0.21               234
# 16                               6               0.44                52
# 17                              12               0.08               232
# 18                              12               0.08               232
# 19                              12               0.10               249
# 20                               4               2.21               261
# 21                               4               0.65               261
# 22                               1               2.45               165
# 23                               1               0.42                52
# 24                               1               0.21               264
# 25                               4               0.62               261
# 26                               1               0.91                81
# 27                               1               0.17                63
# 28                               2               4.46               103
# 29                               2               1.76               103
#
#       borough                                 neighbourhood_name
# 0   Manhattan                                            Midtown
# 1        None  Downtown, Chinatown, Penn Quarters, Mount Vern...
# 2        None                                 Historic Anacostia
# 3        None                                        East Boston
# 4        None  Edgewood, Bloomingdale, Truxton Circle, Eckington
# 5        None                         Capitol Hill, Lincoln Park
# 6        None                                            Roxbury
# 7        None     Kalorama Heights, Adams Morgan, Lanier Heights
# 8        None                                            Roxbury
# 9    Brooklyn                                       Williamsburg
# 10  Manhattan                                        East Harlem
# 11  Manhattan                                        East Harlem
# 12   Brooklyn                                        Fort Greene
# 13       None  Spring Valley, Palisades, Wesley Heights, Foxh...
# 14   Brooklyn                                 Bedford-Stuyvesant
# 15       None                                        Beacon Hill
# 16   Brooklyn                                 Bedford-Stuyvesant
# 17       None                                           Back Bay
# 18       None                                           Back Bay
# 19       None                                          North End
# 20       None     Cathedral Heights, McLean Gardens, Glover Park
# 21       None     Cathedral Heights, McLean Gardens, Glover Park
# 22     Queens                                   Long Island City
# 23   Brooklyn                                 Bedford-Stuyvesant
# 24       None  Columbia Heights, Mt. Pleasant, Pleasant Plain...
# 25       None     Cathedral Heights, McLean Gardens, Glover Park
# 26   Brooklyn                                         Greenpoint
# 27   Brooklyn                                       Clinton Hill
# 28  Manhattan                                       East Village
# 29  Manhattan                                       East Village
#
# [30 rows x 29 columns]

# %%
# Statistics
stats = pd.read_sql_query("""
    SELECT 
        COUNT(*) as total_listings,
        ROUND(AVG(price), 2) as avg_price,
        MIN(price) as min_price,
        MAX(price) as max_price,
        ROUND(AVG(accommodates), 2) as avg_accommodates,
        ROUND(AVG(review_scores_rating), 2) as avg_rating
    FROM listing
""", conn)
print("📊 Listing Statistics:")
stats
# Out:
# 📊 Listing Statistics:
#    total_listings  avg_price  min_price  max_price  avg_accommodates  \
# 0           20631     184.85       10.0     1000.0              2.99
#
#    avg_rating
# 0        4.74

# %% [markdown]
# ## Custom Queries
#
# Add your own queries here to explore the data.

# %%
# Example: Listings by borough
query = """
    SELECT 
        n.borough,
        COUNT(*) as listing_count,
        ROUND(AVG(l.price), 2) as avg_price,
        ROUND(AVG(l.review_scores_rating), 2) as avg_rating
    FROM listing l
    LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
    GROUP BY n.borough
    ORDER BY listing_count DESC
"""
df_borough_stats = pd.read_sql_query(query, conn)
df_borough_stats
# Out:
#          borough  listing_count  avg_price  avg_rating
# 0           None           6509     183.62        4.76
# 1      Manhattan           5501     237.11        4.69
# 2       Brooklyn           5272     168.60        4.77
# 3         Queens           2509     132.56        4.76
# 4          Bronx            604     110.07        4.74
# 5  Staten Island            236     110.64        4.80

# %%
conn.close()
print("✓ Connection closed")
# Out:
# ✓ Connection closed
