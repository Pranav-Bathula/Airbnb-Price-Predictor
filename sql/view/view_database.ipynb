# %% [markdown]
# # Database Viewer
#
# This notebook provides an organized way to view and explore the SQLite database.

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Set up database path
# This notebook is in sql/view/, so we need to go up two levels to get to project root
current_dir = Path().resolve()

# Try different possible locations
if (current_dir / "data").exists():
    # Running from project root
    project_root = current_dir
elif (current_dir.parent / "data").exists():
    # Running from sql/ directory
    project_root = current_dir.parent
elif (current_dir.parent.parent / "data").exists():
    # Running from sql/view/ directory
    project_root = current_dir.parent.parent
else:
    # Fallback: go up two levels from sql/view/
    project_root = current_dir.parent.parent

db_path = project_root / "data" / "airbnb.db"

print(f"Current directory: {current_dir}")
print(f"Project root: {project_root}")
print(f"Database: {db_path}")
print(f"Exists: {db_path.exists()}")
# Out:
# Current directory: /Users/anishj29/Desktop/Github Projects/Airbnb-Price-Predictor/sql/view
# Project root: /Users/anishj29/Desktop/Github Projects/Airbnb-Price-Predictor
# Database: /Users/anishj29/Desktop/Github Projects/Airbnb-Price-Predictor/data/airbnb.db
# Exists: True

# %% [markdown]
# ## Database Overview

# %%
conn = sqlite3.connect(str(db_path))

# Get all tables
tables_query = "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"
tables = pd.read_sql_query(tables_query, conn)
# Filter out system tables and calendar
tables = tables[~tables['name'].isin(['calendar', 'sqlite_sequence'])]
print("📊 Tables in database:")
print(tables)

# Get row counts for each table
print("\n📈 Row counts:")
for table in tables['name']:
    count = pd.read_sql_query(f"SELECT COUNT(*) as count FROM {table}", conn)
    print(f"  {table}: {count['count'].iloc[0]:,} rows")
# Out:
# 📊 Tables in database:
#             name
# 0        listing
# 1  neighbourhood
#
# 📈 Row counts:
#   listing: 27,797 rows
#   neighbourhood: 295 rows

# %% [markdown]
# ## Check City Distribution
#
# Let's verify that listings exist for each city.

# %%
# Check listings by city
city_distribution = pd.read_sql_query("""
    SELECT 
        city,
        COUNT(*) as listing_count,
        AVG(price) as avg_price,
        MIN(price) as min_price,
        MAX(price) as max_price
    FROM listing
    GROUP BY city
    ORDER BY listing_count DESC
""", conn)

print("📊 Listings by City:")
print(city_distribution)

# Specifically check for Boston
boston_count = pd.read_sql_query("""
    SELECT COUNT(*) as count 
    FROM listing 
    WHERE city = 'Boston'
""", conn)

boston_count_value = boston_count['count'].iloc[0]

if boston_count_value > 0:
    print(f"\n✓ Boston listings exist in database: {boston_count_value:,} listings")
    
    # Show sample Boston listings
    print("\n📋 Sample Boston listings:")
    boston_samples = pd.read_sql_query("""
        SELECT 
            listing_id, 
            city,
            price, 
            borough,
            neighbourhood_name,
            accommodates,
            bedrooms,
            host_is_superhost,
            number_of_reviews
        FROM listing l
        LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
        WHERE city = 'Boston'
        LIMIT 10
    """, conn)
    print(boston_samples)
else:
    print(f"\n✗ No Boston listings found in database")
# Out:
# 📊 Listings by City:
#             city  listing_count   avg_price  min_price  max_price
# 0            NYC          19779  578.158299       10.0    50052.0
# 1  Washington DC           4735  397.113622       10.0    50000.0
# 2         Boston           3283  567.583613       26.0    50000.0
#
# ✓ Boston listings exist in database: 3,283 listings
#
# 📋 Sample Boston listings:
#    listing_id    city  price borough neighbourhood_name  accommodates  \
# 0        3781  Boston  125.0    None        East Boston             2
# 1        5506  Boston  129.0    None            Roxbury             2
# 2        6695  Boston  168.0    None            Roxbury             4
# 3        8789  Boston  140.0    None        Beacon Hill             2
# 4       10811  Boston  166.0    None           Back Bay             3
# 5       10813  Boston  202.0    None           Back Bay             2
# 6       10986  Boston  202.0    None          North End             2
# 7       18711  Boston  162.0    None         Dorchester             6
# 8       29765  Boston  323.0    None        Charlestown             2
# 9       40601  Boston   91.0    None      Jamaica Plain             2
#
#    bedrooms  host_is_superhost  number_of_reviews
# 0         1                  1                 26
# 1         1                  1                138
# 2         0                  1                141
# 3         1                  1                 29
# 4         0                  0                  9
# 5         0                  0                  6
# 6         0                  0                  2
# 7         3                  0                 51
# 8         1                  0                103
# 9         1                  1                103

# %% [markdown]
# ## View Neighbourhood Table

# %%
df_neighbourhoods = pd.read_sql_query("SELECT * FROM neighbourhood ORDER BY borough, neighbourhood_name", conn)
print(f"Total neighbourhoods: {len(df_neighbourhoods)}")
print(f"\nBoroughs: {df_neighbourhoods['borough'].unique()}")
df_neighbourhoods.head(20)
# Out:
# Total neighbourhoods: 295
#
# Boroughs: [None 'Bronx' 'Brooklyn' 'Manhattan' 'Queens' 'Staten Island']
#     neighbourhood_id borough  \
# 0                231    None
# 1                232    None
# 2                233    None
# 3                234    None
# 4                235    None
# 5                257    None
# 6                258    None
# 7                259    None
# 8                260    None
# 9                261    None
# 10               236    None
# 11               237    None
# 12               262    None
# 13               263    None
# 14               264    None
# 15               265    None
# 16               266    None
# 17               238    None
# 18               267    None
# 19               239    None
#
#                                    neighbourhood_name
# 0                                             Allston
# 1                                            Back Bay
# 2                                         Bay Village
# 3                                         Beacon Hill
# 4                                            Brighton
# 5                Brightwood Park, Crestwood, Petworth
# 6                       Brookland, Brentwood, Langdon
# 7                          Capitol Hill, Lincoln Park
# 8     Capitol View, Marshall Heights, Benning Heights
# 9      Cathedral Heights, McLean Gardens, Glover Park
# 10                                        Charlestown
# 11                                          Chinatown
# 12  Cleveland Park, Woodley Park, Massachusetts Av...
# 13  Colonial Village, Shepherd Park, North Portal ...
# 14  Columbia Heights, Mt. Pleasant, Pleasant Plain...
# 15   Congress Heights, Bellevue, Washington Highlands
# 16  Deanwood, Burrville, Grant Park, Lincoln Heigh...
# 17                                         Dorchester
# 18                           Douglas, Shipley Terrace
# 19                                           Downtown

# %% [markdown]
# ## View Listing Table

# %%
# Sample listings with neighbourhood info
df_listings = pd.read_sql_query("""
    SELECT city, listing_id, price, borough, neighbourhood_name, 
           accommodates, bedrooms, beds, host_is_superhost, 
           number_of_reviews, review_scores_rating, bathrooms, availability_365
    FROM listing l
    LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
    LIMIT 50
""", conn)
df_listings
# Out:
#              city  listing_id  price    borough  \
# 0             NYC        2595  240.0  Manhattan
# 1   Washington DC        3344  150.0       None
# 2   Washington DC        3686   60.0       None
# 3          Boston        3781  125.0       None
# 4   Washington DC        3943   79.0       None
# 5   Washington DC        4197  128.0       None
# 6          Boston        5506  129.0       None
# 7   Washington DC        5589   87.0       None
# 8          Boston        6695  168.0       None
# 9             NYC        6848   96.0   Brooklyn
# 10            NYC        6872   59.0  Manhattan
# 11            NYC        6990   73.0  Manhattan
# 12            NYC        7097  216.0   Brooklyn
# 13  Washington DC        7103   74.0       None
# 14            NYC        8490  170.0   Brooklyn
# 15         Boston        8789  140.0       None
# 16            NYC       10452   90.0   Brooklyn
# 17         Boston       10811  166.0       None
# 18         Boston       10813  202.0       None
# 19         Boston       10986  202.0       None
# 20  Washington DC       11785   90.0       None
# 21  Washington DC       12442   52.0       None
# 22            NYC       12937  232.0     Queens
# 23            NYC       12940  151.0   Brooklyn
# 24  Washington DC       13744  125.0       None
# 25  Washington DC       14218   64.0       None
# 26            NYC       14314  115.0   Brooklyn
# 27            NYC       16338   57.0   Brooklyn
# 28            NYC       16580  227.0  Manhattan
# 29            NYC       16821  202.0  Manhattan
# 30  Washington DC       17131   64.0       None
# 31            NYC       18152  576.0  Manhattan
# 32         Boston       18711  162.0       None
# 33            NYC       18728  151.0  Manhattan
# 34            NYC       19174  200.0  Manhattan
# 35            NYC       19812   95.0   Brooklyn
# 36            NYC       21456  112.0  Manhattan
# 37            NYC       21794   85.0  Manhattan
# 38            NYC       23545  200.0  Manhattan
# 39            NYC       24285  201.0   Brooklyn
# 40            NYC       26785   90.0   Brooklyn
# 41  Washington DC       27682   70.0       None
# 42            NYC       29013   90.0   Brooklyn
# 43            NYC       29628  149.0   Brooklyn
# 44         Boston       29765  323.0       None
# 45            NYC       31130  170.0  Manhattan
# 46            NYC       31994  122.0   Brooklyn
# 47  Washington DC       32087  229.0       None
# 48            NYC       38663  765.0   Brooklyn
# 49            NYC       39282  147.0   Brooklyn
#
#                                    neighbourhood_name  accommodates  bedrooms  \
# 0                                             Midtown             1         0
# 1   Downtown, Chinatown, Penn Quarters, Mount Vern...             2         1
# 2                                  Historic Anacostia             1         1
# 3                                         East Boston             2         1
# 4   Edgewood, Bloomingdale, Truxton Circle, Eckington             2         1
# 5                          Capitol Hill, Lincoln Park             1         1
# 6                                             Roxbury             2         1
# 7      Kalorama Heights, Adams Morgan, Lanier Heights             3         1
# 8                                             Roxbury             4         0
# 9                                        Williamsburg             3         2
# 10                                        East Harlem             1         1
# 11                                        East Harlem             1         2
# 12                                        Fort Greene             2         1
# 13  Spring Valley, Palisades, Wesley Heights, Foxh...             2         1
# 14                                 Bedford-Stuyvesant             5         1
# 15                                        Beacon Hill             2         1
# 16                                 Bedford-Stuyvesant             2         1
# 17                                           Back Bay             3         0
# 18                                           Back Bay             2         0
# 19                                          North End             2         0
# 20     Cathedral Heights, McLean Gardens, Glover Park             4         1
# 21     Cathedral Heights, McLean Gardens, Glover Park             2         1
# 22                                   Long Island City             3         1
# 23                                 Bedford-Stuyvesant             2         1
# 24  Columbia Heights, Mt. Pleasant, Pleasant Plain...             2         1
# 25     Cathedral Heights, McLean Gardens, Glover Park             2         1
# 26                                         Greenpoint             2         1
# 27                                       Clinton Hill             1         1
# 28                                       East Village             1         1
# 29                                       East Village             1         1
# 30     Cathedral Heights, McLean Gardens, Glover Park             2         1
# 31                                    Upper East Side             2         2
# 32                                         Dorchester             6         3
# 33                                            Chelsea             3         1
# 34                                       West Village             4         1
# 35                                       Williamsburg             2         1
# 36                                    Upper West Side             2         1
# 37                                            Chelsea             2         1
# 38                                             Harlem             2         1
# 39                                         Park Slope             5         3
# 40                                        South Slope             2         1
# 41  Lamont Riggs, Queens Chapel, Fort Totten, Plea...             1         1
# 42                                 Bedford-Stuyvesant             2         1
# 43                                       Clinton Hill             2         1
# 44                                        Charlestown             2         1
# 45                                     Hell's Kitchen             1         1
# 46                                       Clinton Hill             2         1
# 47     Kalorama Heights, Adams Morgan, Lanier Heights             2         1
# 48                                        Boerum Hill             2         5
# 49                                       Williamsburg             2         1
#
#     beds  host_is_superhost  number_of_reviews  review_scores_rating  \
# 0      1                  0                 47                  4.68
# 1      3                  0                 10                  5.00
# 2      2                  0                 84                  4.64
# 3      1                  1                 26                  4.96
# 4      1                  1                546                  4.86
# 5      1                  1                 67                  4.88
# 6      1                  1                138                  4.82
# 7      1                  0                 96                  4.50
# 8      2                  1                141                  4.81
# 9      1                  1                195                  4.59
# 10     1                  0                  1                  5.00
# 11     2                  0                249                  4.88
# 12     2                  1                423                  4.89
# 13     2                  1                 91                  4.79
# 14     4                  0                189                  4.77
# 15     2                  1                 29                  4.69
# 16     2                  1                 82                  4.66
# 17     1                  0                  9                  4.33
# 18     1                  0                  6                  5.00
# 19     1                  0                  2                  4.50
# 20     3                  1                416                  4.59
# 21     1                  1                120                  4.62
# 22     2                  0                456                  4.92
# 23     1                  0                 80                  4.58
# 24     2                  0                 38                  4.84
# 25     1                  1                106                  4.62
# 26     2                  0                176                  4.83
# 27     2                  0                 32                  4.66
# 28     1                  1                658                  4.81
# 29     1                  1                281                  4.74
# 30     1                  1                109                  4.66
# 31     1                  0                146                  4.41
# 32     3                  0                 51                  4.30
# 33     1                  1                251                  4.95
# 34     3                  0                 68                  4.63
# 35     2                  0                 58                  4.48
# 36     0                  0                 79                  4.69
# 37     1                  0                 36                  4.97
# 38     2                  1                214                  4.75
# 39     7                  0                 93                  4.83
# 40     3                  0                479                  4.93
# 41     1                  1                 12                  5.00
# 42     1                  1                 78                  4.74
# 43     1                  1                490                  4.95
# 44     1                  0                103                  4.97
# 45     1                  0                 75                  4.89
# 46     1                  0                621                  4.55
# 47     1                  1                 16                  4.87
# 48     5                  0                 43                  4.70
# 49     1                  1                284                  4.83
#
#     bathrooms  availability_365
# 0         1.0               289
# 1         1.0               362
# 2         1.0               298
# 3         1.0               326
# 4         1.0               331
# 5         1.5               346
# 6         1.0                67
# 7         1.0               133
# 8         1.0                56
# 9         1.0               285
# 10        1.0                83
# 11        1.0               186
# 12        1.0                 0
# 13        1.0               319
# 14        1.0               275
# 15        1.0               277
# 16        1.0               244
# 17        1.0               218
# 18        1.0               117
# 19        1.0               330
# 20        1.0               269
# 21        1.5               303
# 22        1.0               203
# 23        1.0               286
# 24        1.0               225
# 25        1.5               287
# 26        1.0               300
# 27        1.0               335
# 28        1.0               226
# 29        1.0                28
# 30        1.5               321
# 31        1.0               365
# 32        1.0               286
# 33        1.5               353
# 34        1.0               290
# 35        1.0               306
# 36        1.0               286
# 37        1.0               364
# 38        1.0               358
# 39        3.0               360
# 40        1.0                93
# 41        1.0               287
# 42        1.0               282
# 43        1.0               299
# 44        1.0               173
# 45        1.0               335
# 46        1.0               253
# 47        1.0               330
# 48        2.5               364
# 49        1.0                25

# %%
# Statistics
stats = pd.read_sql_query("""
    SELECT 
        COUNT(*) as total_listings,
        ROUND(AVG(price), 2) as avg_price,
        MIN(price) as min_price,
        MAX(price) as max_price,
        ROUND(AVG(accommodates), 2) as avg_accommodates,
        ROUND(AVG(review_scores_rating), 2) as avg_rating
    FROM listing
""", conn)
print("📊 Listing Statistics:")
stats
# Out:
# 📊 Listing Statistics:
#    total_listings  avg_price  min_price  max_price  avg_accommodates  \
# 0           27797     546.07       10.0    50052.0              3.05
#
#    avg_rating
# 0        4.74

# %% [markdown]
# ## Custom Queries
#
# Add your own queries here to explore the data.

# %%
# Example: Listings by borough
query = """
    SELECT 
        n.borough,
        COUNT(*) as listing_count,
        ROUND(AVG(l.price), 2) as avg_price,
        ROUND(AVG(l.review_scores_rating), 2) as avg_rating
    FROM listing l
    LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
    GROUP BY n.borough
    ORDER BY listing_count DESC
"""
df_borough_stats = pd.read_sql_query(query, conn)
df_borough_stats
# Out:
#          borough  listing_count  avg_price  avg_rating
# 0      Manhattan           8249    1038.32        4.69
# 1           None           8018     466.91        4.76
# 2       Brooklyn           7217     247.98        4.77
# 3         Queens           3201     292.69        4.76
# 4          Bronx            808     130.43        4.74
# 5  Staten Island            304     126.09        4.79

# %%
conn.close()
print("✓ Connection closed")
# Out:
# ✓ Connection closed
