# %% [markdown]
# # Database Viewer
#
# This notebook provides an organized way to view and explore the SQLite database.

# %%
import sqlite3
import pandas as pd
from pathlib import Path

# Set up database path
# This notebook is in sql/view/, so we need to go up two levels to get to project root
current_dir = Path().resolve()

# Try different possible locations
if (current_dir / "data").exists():
    # Running from project root
    project_root = current_dir
elif (current_dir.parent / "data").exists():
    # Running from sql/ directory
    project_root = current_dir.parent
elif (current_dir.parent.parent / "data").exists():
    # Running from sql/view/ directory
    project_root = current_dir.parent.parent
else:
    # Fallback: go up two levels from sql/view/
    project_root = current_dir.parent.parent

db_path = project_root / "data" / "airbnb.db"

print(f"Current directory: {current_dir}")
print(f"Project root: {project_root}")
print(f"Database: {db_path}")
print(f"Exists: {db_path.exists()}")
# Out:
# Current directory: /Users/pranavbathula/Library/CloudStorage/Box-Box/DATA MANAGEMENT FOR DATA SCIENCE/Airbnb-Price-Predictor/sql/view
# Project root: /Users/pranavbathula/Library/CloudStorage/Box-Box/DATA MANAGEMENT FOR DATA SCIENCE/Airbnb-Price-Predictor
# Database: /Users/pranavbathula/Library/CloudStorage/Box-Box/DATA MANAGEMENT FOR DATA SCIENCE/Airbnb-Price-Predictor/data/airbnb.db
# Exists: True

# %% [markdown]
# ## Database Overview

# %%
conn = sqlite3.connect(str(db_path))

# Get all tables
tables_query = "SELECT name FROM sqlite_master WHERE type='table' ORDER BY name;"
tables = pd.read_sql_query(tables_query, conn)
# Filter out system tables and calendar
tables = tables[~tables['name'].isin(['calendar', 'sqlite_sequence'])]
print("📊 Tables in database:")
print(tables)

# Get row counts for each table
print("\n📈 Row counts:")
for table in tables['name']:
    count = pd.read_sql_query(f"SELECT COUNT(*) as count FROM {table}", conn)
    print(f"  {table}: {count['count'].iloc[0]:,} rows")
# Out:
# 📊 Tables in database:
#             name
# 0        listing
# 1  neighbourhood
#
# 📈 Row counts:
#   listing: 14,436 rows
#   neighbourhood: 230 rows

# %% [markdown]
# ## View Neighbourhood Table

# %%
df_neighbourhoods = pd.read_sql_query("SELECT * FROM neighbourhood ORDER BY borough, neighbourhood_name", conn)
print(f"Total neighbourhoods: {len(df_neighbourhoods)}")
print(f"\nBoroughs: {df_neighbourhoods['borough'].unique()}")
df_neighbourhoods.head(20)
# Out:
# Total neighbourhoods: 230
#
# Boroughs: ['Bronx' 'Brooklyn' 'Manhattan' 'Queens' 'Staten Island']
#     neighbourhood_id borough neighbourhood_name
# 0                  1   Bronx           Allerton
# 1                  2   Bronx         Baychester
# 2                  3   Bronx            Belmont
# 3                  4   Bronx          Bronxdale
# 4                  5   Bronx        Castle Hill
# 5                  6   Bronx        City Island
# 6                  7   Bronx  Claremont Village
# 7                  8   Bronx       Clason Point
# 8                 11   Bronx         Co-op City
# 9                  9   Bronx          Concourse
# 10                10   Bronx  Concourse Village
# 11                12   Bronx       Country Club
# 12                14   Bronx    East Morrisania
# 13                13   Bronx        Eastchester
# 14                15   Bronx           Edenwald
# 15                16   Bronx          Fieldston
# 16                17   Bronx            Fordham
# 17                18   Bronx         Highbridge
# 18                19   Bronx        Hunts Point
# 19                20   Bronx        Kingsbridge

# %% [markdown]
# ## View Listing Table

# %%
# Sample listings with neighbourhood info
df_listings = pd.read_sql_query("""
    SELECT listing_id, price, borough, neighbourhood_name, 
           accommodates, bedrooms, beds, host_is_superhost, 
           number_of_reviews, review_scores_rating, bathrooms, availability_365
    FROM listing l
    LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
    LIMIT 30
""", conn)
df_listings
# Out:
#     listing_id  price    borough  neighbourhood_name  accommodates  bedrooms  \
# 0         2595  240.0  Manhattan             Midtown             1         0
# 1         6848   96.0   Brooklyn        Williamsburg             3         2
# 2         6872   59.0  Manhattan         East Harlem             1         1
# 3         6990   73.0  Manhattan         East Harlem             1         2
# 4         7097  216.0   Brooklyn         Fort Greene             2         1
# 5         8490  170.0   Brooklyn  Bedford-Stuyvesant             5         1
# 6        10452   90.0   Brooklyn  Bedford-Stuyvesant             2         1
# 7        12937  232.0     Queens    Long Island City             3         1
# 8        12940  151.0   Brooklyn  Bedford-Stuyvesant             2         1
# 9        14314  115.0   Brooklyn          Greenpoint             2         1
# 10       16338   57.0   Brooklyn        Clinton Hill             1         1
# 11       16580  227.0  Manhattan        East Village             1         1
# 12       16821  202.0  Manhattan        East Village             1         1
# 13       18152  576.0  Manhattan     Upper East Side             2         2
# 14       18728  151.0  Manhattan             Chelsea             3         1
# 15       19174  200.0  Manhattan        West Village             4         1
# 16       19812   95.0   Brooklyn        Williamsburg             2         1
# 17       21456  112.0  Manhattan     Upper West Side             2         1
# 18       21794   85.0  Manhattan             Chelsea             2         1
# 19       23545  200.0  Manhattan              Harlem             2         1
# 20       24285  201.0   Brooklyn          Park Slope             5         3
# 21       26785   90.0   Brooklyn         South Slope             2         1
# 22       29013   90.0   Brooklyn  Bedford-Stuyvesant             2         1
# 23       29628  149.0   Brooklyn        Clinton Hill             2         1
# 24       31130  170.0  Manhattan      Hell's Kitchen             1         1
# 25       31994  122.0   Brooklyn        Clinton Hill             2         1
# 26       38663  765.0   Brooklyn         Boerum Hill             2         5
# 27       39282  147.0   Brooklyn        Williamsburg             2         1
# 28       42300  563.0  Manhattan     Lower East Side             5         3
# 29       42729  254.0   Brooklyn     Carroll Gardens             2         1
#
#     beds  host_is_superhost  number_of_reviews  review_scores_rating  \
# 0      1                  0                 47                  4.68
# 1      1                  1                195                  4.59
# 2      1                  0                  1                  5.00
# 3      2                  0                249                  4.88
# 4      2                  1                423                  4.89
# 5      4                  0                189                  4.77
# 6      2                  1                 82                  4.66
# 7      2                  0                456                  4.92
# 8      1                  0                 80                  4.58
# 9      2                  0                176                  4.83
# 10     2                  0                 32                  4.66
# 11     1                  1                658                  4.81
# 12     1                  1                281                  4.74
# 13     1                  0                146                  4.41
# 14     1                  1                251                  4.95
# 15     3                  0                 68                  4.63
# 16     2                  0                 58                  4.48
# 17     0                  0                 79                  4.69
# 18     1                  0                 36                  4.97
# 19     2                  1                214                  4.75
# 20     7                  0                 93                  4.83
# 21     3                  0                479                  4.93
# 22     1                  1                 78                  4.74
# 23     1                  1                490                  4.95
# 24     1                  0                 75                  4.89
# 25     1                  0                621                  4.55
# 26     5                  0                 43                  4.70
# 27     1                  1                284                  4.83
# 28     4                  0                 70                  4.80
# 29     1                  0                219                  4.67
#
#     bathrooms  availability_365
# 0         1.0               289
# 1         1.0               285
# 2         1.0                83
# 3         1.0               186
# 4         1.0                 0
# 5         1.0               275
# 6         1.0               244
# 7         1.0               203
# 8         1.0               286
# 9         1.0               300
# 10        1.0               335
# 11        1.0               226
# 12        1.0                28
# 13        1.0               365
# 14        1.5               353
# 15        1.0               290
# 16        1.0               306
# 17        1.0               286
# 18        1.0               364
# 19        1.0               358
# 20        3.0               360
# 21        1.0                93
# 22        1.0               282
# 23        1.0               299
# 24        1.0               335
# 25        1.0               253
# 26        2.5               364
# 27        1.0                25
# 28        2.0               185
# 29        1.0               364

# %%
# Statistics
stats = pd.read_sql_query("""
    SELECT 
        COUNT(*) as total_listings,
        ROUND(AVG(price), 2) as avg_price,
        MIN(price) as min_price,
        MAX(price) as max_price,
        ROUND(AVG(accommodates), 2) as avg_accommodates,
        ROUND(AVG(review_scores_rating), 2) as avg_rating
    FROM listing
""", conn)
print("📊 Listing Statistics:")
stats
# Out:
# 📊 Listing Statistics:
#    total_listings  avg_price  min_price  max_price  avg_accommodates  \
# 0           14436     315.92       10.0    50052.0              2.91
#
#    avg_rating
# 0        4.74

# %% [markdown]
# ## Custom Queries
#
# Add your own queries here to explore the data.

# %%
# Example: Listings by borough
query = """
    SELECT 
        n.borough,
        COUNT(*) as listing_count,
        ROUND(AVG(l.price), 2) as avg_price,
        ROUND(AVG(l.review_scores_rating), 2) as avg_rating
    FROM listing l
    LEFT JOIN neighbourhood n ON l.neighbourhood_id = n.neighbourhood_id
    GROUP BY n.borough
    ORDER BY listing_count DESC
"""
df_borough_stats = pd.read_sql_query(query, conn)
df_borough_stats
# Out:
#          borough  listing_count  avg_price  avg_rating
# 0      Manhattan           5706     533.42        4.69
# 1       Brooklyn           5345     189.84        4.77
# 2         Queens           2534     156.16        4.76
# 3          Bronx            611     127.53        4.74
# 4  Staten Island            240     119.11        4.79

# %%
conn.close()
print("✓ Connection closed")
# Out:
# ✓ Connection closed
