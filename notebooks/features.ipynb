# %%
import pandas as pd
import numpy as np
import os

# Read the cleaned listings CSV (output from clean_csvs.ipynb)
df_clean = pd.read_csv("../data/processed/listings_cleaned.csv")
print(f"Data shape: {df_clean.shape}")
df_clean.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  40824219  https://www.airbnb.com/rooms/40824219  20251001171547
# 1  40833186  https://www.airbnb.com/rooms/40833186  20251001171547
# 2  40837137  https://www.airbnb.com/rooms/40837137  20251001171547
# 3  40838018  https://www.airbnb.com/rooms/40838018  20251001171547
# 4  40839416  https://www.airbnb.com/rooms/40839416  20251001171547
#
#   last_scraped           source                                         name  \
# 0   2025-10-02      city scrape   Room close to  Manhattan for FEMALE guests
# 1   2025-10-02  previous scrape  Soho LES East village private room downtown
# 2   2025-10-02  previous scrape     Sunset Park - Quiet and close to subway!
# 3   2025-10-02  previous scrape             Cozy One Bedroom in Clinton Hill
# 4   2025-10-02      city scrape    🪴XL dojo 🌾 shared green yogi palace apt 🌿
#
#                                          description  \
# 0  This cozy spacious room includes a twin size b...
# 1                                                NaN
# 2  Cozy, lovely bedroom with a comfortable full s...
# 3  This sunny one-bedroom apartment is located in...
# 4  New York City living at its best. A massive, c...
#
#                                neighborhood_overview  \
# 0  Sunnyside is a safe residental area. <br />The...
# 1                                                NaN
# 2                        the sunset park of Brooklyn
# 3  Clinton Hill is one of the best neighborhoods ...
# 4  Live like the Ramones > The East Village is st...
#
#                                          picture_url    host_id  ...  \
# 0  https://a0.muscache.com/pictures/hosting/Hosti...  317540555  ...
# 1  https://a0.muscache.com/pictures/1f093bbc-936c...   68718914  ...
# 2  https://a0.muscache.com/pictures/01c4e91e-4012...  317770098  ...
# 3  https://a0.muscache.com/pictures/9322d54a-6eb7...   17211451  ...
# 4  https://a0.muscache.com/pictures/hosting/Hosti...    4765305  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.88                   4.94                4.69
# 1                         NaN                    NaN                 NaN
# 2                        5.00                   5.00                5.00
# 3                        5.00                   5.00                5.00
# 4                        5.00                   5.00                4.95
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              3
# 1     NaN                t                              1
# 2     NaN                f                              1
# 3     NaN                t                              1
# 4     NaN                f                              8
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           0
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            3
# 1                                            1
# 2                                            1
# 3                                            0
# 4                                            8
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.23
# 1                                           0               NaN
# 2                                           0              0.01
# 3                                           0              0.01
# 4                                           0              0.40
#
# [5 rows x 79 columns]

# %%
# Create new features from cleaned data
listing_features = pd.DataFrame()

listing_features["listing_id"] = df_clean["id"]

listing_features["price"] = df_clean["price"]

listing_features["borough"] = df_clean["neighbourhood_group_cleansed"]
listing_features["neighbourhood_name"] = df_clean["neighbourhood_cleansed"]

listing_features["accommodates"] = df_clean["accommodates"]
listing_features["bedrooms"] = df_clean["bedrooms"]
listing_features["beds"] = df_clean["beds"]

accom = listing_features["accommodates"].replace(0, np.nan)
listing_features["price_per_accommodate"] = listing_features["price"] / accom

listing_features["host_is_superhost"] = df_clean["host_is_superhost"]
listing_features["number_of_reviews"] = df_clean["number_of_reviews"]
listing_features["review_scores_rating"] = df_clean["review_scores_rating"]
listing_features["availability_365"] = df_clean["availability_365"]

listing_features.head()

# %%
# Save features to CSV
os.makedirs("../data/processed", exist_ok=True)

out_path = "../data/processed/listing_features.csv"
listing_features.to_csv(out_path, index=False)

print(f"Features saved to: {out_path}")
out_path
# Out:
#    listing_id  price    borough neighbourhood_name  accommodates  bedrooms  \
# 0    40824219   66.0     Queens          Sunnyside             1       1.0
# 4    40839416   76.0  Manhattan       East Village             1       1.0
# 5    40843980   97.0     Queens         Ozone Park             6       2.0
# 7    40824301   60.0   Brooklyn       Williamsburg             1       2.0
# 8    40825740  425.0   Brooklyn      Crown Heights             6       3.0
#
#    beds  price_per_accommodate host_is_superhost  number_of_reviews  \
# 0   1.0              66.000000                 t                 16
# 4   1.0              76.000000                 t                 20
# 5   3.0              16.166667                 t                 93
# 7   1.0              60.000000                 t                 26
# 8   3.0              70.833333                 f                  1
#
#    review_scores_rating  availability_365
# 0                  4.81                77
# 4                  4.95               168
# 5                  4.14               364
# 7                  4.92               187
# 8                  5.00               224

# %%
# Out:
# '../data/processed/listing_features.csv'
